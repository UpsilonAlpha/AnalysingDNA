# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_dna = pd.read_csv("G9_liver_dna-meth.csv")
df_dna
# Out:
#           Unnamed: 0          Label  cg00005740  cg00012529  cg00013196  \
# 0    TCGA.2V.A95S.01  Primary Tumor    0.601838    0.374335    0.300235
# 1    TCGA.2Y.A9GS.01  Primary Tumor    0.399472    0.395836    0.395846
# 2    TCGA.2Y.A9GT.01  Primary Tumor    0.438239    0.640740    0.477210
# 3    TCGA.2Y.A9GU.01  Primary Tumor    0.913263    0.969171    0.944687
# 4    TCGA.2Y.A9GV.01  Primary Tumor    0.648241    0.805019    0.560080
# ..               ...            ...         ...         ...         ...
# 422  TCGA.ZP.A9D4.01  Primary Tumor    0.524637    0.463510    0.326134
# 423  TCGA.ZS.A9CD.01  Primary Tumor    0.842984    0.728447    0.448321
# 424  TCGA.ZS.A9CE.01  Primary Tumor    0.085340    0.360370    0.269926
# 425  TCGA.ZS.A9CF.01  Primary Tumor    0.365498    0.341860    0.140982
# 426  TCGA.ZS.A9CG.01  Primary Tumor    0.519463    0.746466    0.258855
#
#      cg00019366  cg00028598  cg00030627  cg00033551  cg00047815  ...  \
# 0      0.259656    0.311692    0.331413    0.963102    0.586768  ...
# 1      0.380457    0.273681    0.446539    0.952035    0.380159  ...
# 2      0.519875    0.377109    0.450508    0.604261    0.558608  ...
# 3      0.573213    0.944506    0.934732    0.909746    0.883221  ...
# 4      0.914805    0.389027    0.641507    0.218462    0.559733  ...
# ..          ...         ...         ...         ...         ...  ...
# 422    0.437509    0.047701    0.088209    0.120546    0.495788  ...
# 423    0.751513    0.344487    0.589816    0.970558    0.742978  ...
# 424    0.200526    0.052357    0.107893    0.159162    0.163846  ...
# 425    0.491438    0.095861    0.155036    0.425209    0.263284  ...
# 426    0.466755    0.485708    0.314122    0.201272    0.626390  ...
#
#      rs7660805  rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# 0     0.944546   0.959710  0.969422  0.368036  0.513791   0.509061   0.541551
# 1     0.334419   0.459250  0.971834  0.933756  0.521390   0.020679   0.573997
# 2     0.511502   0.462957  0.018341  0.951748  0.544744   0.025068   0.558837
# 3     0.540377   0.487190  0.015734  0.945182  0.020356   0.521952   0.939739
# 4     0.948858   0.957963  0.016105  0.940811  0.569243   0.967371   0.518856
# ..         ...        ...       ...       ...       ...        ...        ...
# 422   0.947388   0.488338  0.457428  0.087709  0.018182   0.022922   0.643866
# 423   0.943960   0.433075  0.017762  0.071625  0.506783   0.515989   0.041040
# 424   0.085488   0.501397  0.016892  0.894595  0.015875   0.964770   0.602386
# 425   0.556033   0.025535  0.018763  0.036116  0.967576   0.970147   0.912522
# 426   0.563591   0.021717  0.964600  0.359823  0.517733   0.513286   0.066106
#
#      rs939290  rs951295  rs966367
# 0    0.562851  0.495167  0.048576
# 1    0.960284  0.037918  0.473765
# 2    0.966630  0.968370  0.948648
# 3    0.966117  0.027995  0.949593
# 4    0.523212  0.506449  0.037212
# ..        ...       ...       ...
# 422  0.956754  0.963627  0.493371
# 423  0.034835  0.036805  0.900137
# 424  0.421954  0.503566  0.551313
# 425  0.963320  0.845742  0.468968
# 426  0.267345  0.949555  0.531594
#
# [427 rows x 5002 columns]

# %%
df_gene = pd.read_csv("G9_liver_gene-expr.csv")
df_gene
# Out:
#           Unnamed: 0          Label  X..100130426  X..100133144  X..100134869  \
# 0    TCGA.2V.A95S.01  Primary Tumor           0.0        1.5051        3.7074
# 1    TCGA.2Y.A9GS.01  Primary Tumor           0.0       26.4120        2.6663
# 2    TCGA.2Y.A9GT.01  Primary Tumor           0.0        0.0000        4.4833
# 3    TCGA.2Y.A9GU.01  Primary Tumor           0.0        5.7222        5.1216
# 4    TCGA.2Y.A9GV.01  Primary Tumor           0.0       11.4975        5.4230
# ..               ...            ...           ...           ...           ...
# 416  TCGA.ZP.A9D4.01  Primary Tumor           0.0        1.0069        6.9127
# 417  TCGA.ZS.A9CD.01  Primary Tumor           0.0        4.2224        1.7881
# 418  TCGA.ZS.A9CE.01  Primary Tumor           0.0        0.0000        8.7527
# 419  TCGA.ZS.A9CF.01  Primary Tumor           0.0        7.3398        9.8897
# 420  TCGA.ZS.A9CG.01  Primary Tumor           0.0        0.0000        8.2262
#
#      X..10357   X..10431  X..136542  X..155060  X..26823  ...  ZXDA.7789  \
# 0     90.1124  1017.1038        0.0   141.3911    0.6516  ...    24.7597
# 1     71.0054   639.2311        0.0   122.7206    1.4786  ...    68.5067
# 2     95.5122   742.4344        0.0    95.0460    1.7933  ...    46.6263
# 3     61.6679  1186.9807        0.0   280.2709    0.8341  ...    18.3511
# 4    104.4670   878.1726        0.0   282.5719    0.0000  ...    41.4552
# ..        ...        ...        ...        ...       ...  ...        ...
# 416   71.2827   685.0516        0.0    24.3247    0.0000  ...    41.2954
# 417   64.5605  1087.9038        0.0    41.3223    0.0000  ...    30.0526
# 418   64.9891  1119.2560        0.0    35.0109    0.0000  ...    33.3698
# 419  105.8856   544.4521        0.0   262.5775    0.0000  ...    55.8236
# 420   57.1654   917.9092        0.0    96.6581    0.0000  ...    34.2759
#
#      ZXDB.158586  ZXDC.79364  ZYG11A.440590  ZYG11B.79699   ZYX.7791  \
# 0       273.6602    794.2662        18.2440      499.1041  3172.5037
# 1       632.8241   1153.7703        71.4638     1000.4929  5301.1336
# 2      1219.4575   1133.3782        12.5532     1289.3970  3219.0092
# 3       285.2758   1150.2786         9.1755      941.7437  3092.9899
# 4       999.1540   1631.9797         4.2301     1380.7107  2902.7073
# ..           ...         ...            ...           ...        ...
# 416     797.0584   1006.9297         2.2628     1239.4287  2386.0840
# 417    1253.1931    773.8542         7.5131     1238.1668  4028.5500
# 418     248.9059    975.9300        28.9934      882.9322  4041.5755
# 419    1332.1847   1458.3046        55.1344     1257.0641  1172.2950
# 420     237.8749    856.8980        89.8029     2052.4422  1963.3248
#
#      ZZEF1.23140  ZZZ3.26009  psiTPTE22.387590  tAKR.389932
# 0       890.0472    510.1808            3.9094       6.5157
# 1       755.5446    860.5224            6.4071     482.9966
# 2       860.7935    523.6494           14.3466      83.3894
# 3      1339.6283    343.6655            2.5024       2.5024
# 4       575.2961    665.8206            2.5381     119.2893
# ..           ...         ...               ...          ...
# 416     405.0346    791.4015            3.3941     309.9986
# 417     635.6123    434.2600            6.7618     196.0932
# 418     491.7943    577.1335            0.0000     124.7265
# 419     431.4266    836.6644            2.7567     124.0524
# 420     629.9914    622.4507            5.4841     112.4250
#
# [421 rows x 20533 columns]

# %% [markdown]
# normalization or standatarlization

# %%
print(df_dna.describe())
# Out:
#        cg00005740  cg00012529  cg00013196  cg00019366  cg00028598  cg00030627  \
# count  427.000000  427.000000  427.000000  427.000000  427.000000  427.000000
# mean     0.582281    0.639985    0.561627    0.550916    0.548317    0.601201
# std      0.310583    0.303628    0.309317    0.295205    0.343076    0.293078
# min      0.039608    0.062012    0.053980    0.044230    0.023959    0.062076
# 25%      0.288952    0.361260    0.263254    0.281999    0.225844    0.324903
# 50%      0.635024    0.666056    0.511991    0.545151    0.508285    0.626756
# 75%      0.887110    0.965430    0.913352    0.860621    0.932278    0.906213
# max      0.976405    0.985192    0.959916    0.957345    0.981789    0.960817
#
#        cg00033551  cg00047815  cg00049102  cg00049709  ...   rs7660805  \
# count  427.000000  427.000000  427.000000  427.000000  ...  427.000000
# mean     0.724739    0.620792    0.629298    0.548121  ...    0.591112
# std      0.310305    0.289005    0.291637    0.286677  ...    0.330201
# min      0.025082    0.056208    0.054950    0.051349  ...    0.025750
# 25%      0.423453    0.360460    0.358055    0.275104  ...    0.462075
# 50%      0.937383    0.666963    0.695542    0.508115  ...    0.561440
# 75%      0.968806    0.912158    0.916127    0.847222  ...    0.940695
# max      0.986276    0.964061    0.964045    0.962180  ...    0.975499
#
#         rs7746156    rs798149    rs845016    rs877309   rs9292570   rs9363764  \
# count  427.000000  427.000000  427.000000  427.000000  427.000000  427.000000
# mean     0.577177    0.545631    0.444666    0.385080    0.514060    0.642696
# std      0.346058    0.434180    0.328879    0.336497    0.353697    0.321497
# min      0.017123    0.010862    0.029935    0.011137    0.015861    0.019565
# 25%      0.440037    0.018502    0.068978    0.019419    0.036669    0.519087
# 50%      0.495198    0.484135    0.451876    0.495572    0.506229    0.615203
# 75%      0.958705    0.968286    0.798574    0.549994    0.956595    0.936819
# max      0.973883    0.980037    0.960921    0.975837    0.977459    0.964556
#
#          rs939290    rs951295    rs966367
# count  427.000000  427.000000  427.000000
# mean     0.562312    0.447876    0.421236
# std      0.352195    0.322072    0.311345
# min      0.017741    0.027191    0.023094
# 25%      0.406903    0.048260    0.046926
# 50%      0.544963    0.514316    0.473344
# 75%      0.956633    0.549982    0.541053
# max      0.977682    0.978362    0.963037
#
# [8 rows x 5000 columns]

# %%
print(df_dna.isnull().sum())
df_dna_dropna = df_dna.dropna()
# Out:
# Unnamed: 0    0
# Label         0
# cg00005740    0
# cg00012529    0
# cg00013196    0
#              ..
# rs9292570     0
# rs9363764     0
# rs939290      0
# rs951295      0
# rs966367      0
# Length: 5002, dtype: int64

# %%
df_dna_dropna
# Out:
#           Unnamed: 0          Label  cg00005740  cg00012529  cg00013196  \
# 0    TCGA.2V.A95S.01  Primary Tumor    0.601838    0.374335    0.300235
# 1    TCGA.2Y.A9GS.01  Primary Tumor    0.399472    0.395836    0.395846
# 2    TCGA.2Y.A9GT.01  Primary Tumor    0.438239    0.640740    0.477210
# 3    TCGA.2Y.A9GU.01  Primary Tumor    0.913263    0.969171    0.944687
# 4    TCGA.2Y.A9GV.01  Primary Tumor    0.648241    0.805019    0.560080
# ..               ...            ...         ...         ...         ...
# 422  TCGA.ZP.A9D4.01  Primary Tumor    0.524637    0.463510    0.326134
# 423  TCGA.ZS.A9CD.01  Primary Tumor    0.842984    0.728447    0.448321
# 424  TCGA.ZS.A9CE.01  Primary Tumor    0.085340    0.360370    0.269926
# 425  TCGA.ZS.A9CF.01  Primary Tumor    0.365498    0.341860    0.140982
# 426  TCGA.ZS.A9CG.01  Primary Tumor    0.519463    0.746466    0.258855
#
#      cg00019366  cg00028598  cg00030627  cg00033551  cg00047815  ...  \
# 0      0.259656    0.311692    0.331413    0.963102    0.586768  ...
# 1      0.380457    0.273681    0.446539    0.952035    0.380159  ...
# 2      0.519875    0.377109    0.450508    0.604261    0.558608  ...
# 3      0.573213    0.944506    0.934732    0.909746    0.883221  ...
# 4      0.914805    0.389027    0.641507    0.218462    0.559733  ...
# ..          ...         ...         ...         ...         ...  ...
# 422    0.437509    0.047701    0.088209    0.120546    0.495788  ...
# 423    0.751513    0.344487    0.589816    0.970558    0.742978  ...
# 424    0.200526    0.052357    0.107893    0.159162    0.163846  ...
# 425    0.491438    0.095861    0.155036    0.425209    0.263284  ...
# 426    0.466755    0.485708    0.314122    0.201272    0.626390  ...
#
#      rs7660805  rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# 0     0.944546   0.959710  0.969422  0.368036  0.513791   0.509061   0.541551
# 1     0.334419   0.459250  0.971834  0.933756  0.521390   0.020679   0.573997
# 2     0.511502   0.462957  0.018341  0.951748  0.544744   0.025068   0.558837
# 3     0.540377   0.487190  0.015734  0.945182  0.020356   0.521952   0.939739
# 4     0.948858   0.957963  0.016105  0.940811  0.569243   0.967371   0.518856
# ..         ...        ...       ...       ...       ...        ...        ...
# 422   0.947388   0.488338  0.457428  0.087709  0.018182   0.022922   0.643866
# 423   0.943960   0.433075  0.017762  0.071625  0.506783   0.515989   0.041040
# 424   0.085488   0.501397  0.016892  0.894595  0.015875   0.964770   0.602386
# 425   0.556033   0.025535  0.018763  0.036116  0.967576   0.970147   0.912522
# 426   0.563591   0.021717  0.964600  0.359823  0.517733   0.513286   0.066106
#
#      rs939290  rs951295  rs966367
# 0    0.562851  0.495167  0.048576
# 1    0.960284  0.037918  0.473765
# 2    0.966630  0.968370  0.948648
# 3    0.966117  0.027995  0.949593
# 4    0.523212  0.506449  0.037212
# ..        ...       ...       ...
# 422  0.956754  0.963627  0.493371
# 423  0.034835  0.036805  0.900137
# 424  0.421954  0.503566  0.551313
# 425  0.963320  0.845742  0.468968
# 426  0.267345  0.949555  0.531594
#
# [427 rows x 5002 columns]

# %%
# rename the dataset to label
unique_labels = df_dna.iloc[:, 1].unique()

# print the name of the classification
for label in unique_labels:
    print(label)
    
    df_dna = df_dna.rename(columns = {'Primary Tumor':'0'})
df_dna
# Out:
# Primary Tumor
# Solid Tissue Normal
#           Unnamed: 0          Label  cg00005740  cg00012529  cg00013196  \
# 0    TCGA.2V.A95S.01  Primary Tumor    0.601838    0.374335    0.300235
# 1    TCGA.2Y.A9GS.01  Primary Tumor    0.399472    0.395836    0.395846
# 2    TCGA.2Y.A9GT.01  Primary Tumor    0.438239    0.640740    0.477210
# 3    TCGA.2Y.A9GU.01  Primary Tumor    0.913263    0.969171    0.944687
# 4    TCGA.2Y.A9GV.01  Primary Tumor    0.648241    0.805019    0.560080
# ..               ...            ...         ...         ...         ...
# 422  TCGA.ZP.A9D4.01  Primary Tumor    0.524637    0.463510    0.326134
# 423  TCGA.ZS.A9CD.01  Primary Tumor    0.842984    0.728447    0.448321
# 424  TCGA.ZS.A9CE.01  Primary Tumor    0.085340    0.360370    0.269926
# 425  TCGA.ZS.A9CF.01  Primary Tumor    0.365498    0.341860    0.140982
# 426  TCGA.ZS.A9CG.01  Primary Tumor    0.519463    0.746466    0.258855
#
#      cg00019366  cg00028598  cg00030627  cg00033551  cg00047815  ...  \
# 0      0.259656    0.311692    0.331413    0.963102    0.586768  ...
# 1      0.380457    0.273681    0.446539    0.952035    0.380159  ...
# 2      0.519875    0.377109    0.450508    0.604261    0.558608  ...
# 3      0.573213    0.944506    0.934732    0.909746    0.883221  ...
# 4      0.914805    0.389027    0.641507    0.218462    0.559733  ...
# ..          ...         ...         ...         ...         ...  ...
# 422    0.437509    0.047701    0.088209    0.120546    0.495788  ...
# 423    0.751513    0.344487    0.589816    0.970558    0.742978  ...
# 424    0.200526    0.052357    0.107893    0.159162    0.163846  ...
# 425    0.491438    0.095861    0.155036    0.425209    0.263284  ...
# 426    0.466755    0.485708    0.314122    0.201272    0.626390  ...
#
#      rs7660805  rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# 0     0.944546   0.959710  0.969422  0.368036  0.513791   0.509061   0.541551
# 1     0.334419   0.459250  0.971834  0.933756  0.521390   0.020679   0.573997
# 2     0.511502   0.462957  0.018341  0.951748  0.544744   0.025068   0.558837
# 3     0.540377   0.487190  0.015734  0.945182  0.020356   0.521952   0.939739
# 4     0.948858   0.957963  0.016105  0.940811  0.569243   0.967371   0.518856
# ..         ...        ...       ...       ...       ...        ...        ...
# 422   0.947388   0.488338  0.457428  0.087709  0.018182   0.022922   0.643866
# 423   0.943960   0.433075  0.017762  0.071625  0.506783   0.515989   0.041040
# 424   0.085488   0.501397  0.016892  0.894595  0.015875   0.964770   0.602386
# 425   0.556033   0.025535  0.018763  0.036116  0.967576   0.970147   0.912522
# 426   0.563591   0.021717  0.964600  0.359823  0.517733   0.513286   0.066106
#
#      rs939290  rs951295  rs966367
# 0    0.562851  0.495167  0.048576
# 1    0.960284  0.037918  0.473765
# 2    0.966630  0.968370  0.948648
# 3    0.966117  0.027995  0.949593
# 4    0.523212  0.506449  0.037212
# ..        ...       ...       ...
# 422  0.956754  0.963627  0.493371
# 423  0.034835  0.036805  0.900137
# 424  0.421954  0.503566  0.551313
# 425  0.963320  0.845742  0.468968
# 426  0.267345  0.949555  0.531594
#
# [427 rows x 5002 columns]

# %%
df_dna['Label'].value_counts()
# Out:
# Primary Tumor          377
# Solid Tissue Normal     50
# Name: Label, dtype: int64

# %%
# define the dependt variable that need to be predicted 
y = df_dna['Label'].values

# encoding catergorical data
from sklearn.preprocessing import LabelEncoder
Labelencoder = LabelEncoder()
Y = Labelencoder.fit_transform(y) # Primary Tumor = 0, Solid Tissue Normal = 1

# %%
# define x and normalization
# Define the independent variables to drop the Label and Unnamed: 0
X = df_dna.drop(labels = ['Label','Unnamed: 0'], axis = 1)

import numpy as np
feature_names = np.array(X.columns)

# %%
# normalization
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# standard-scaler
scaler = StandardScaler()
scaler.fit(X)
X_scale = scaler.transform(X)
print(X_scale)
print()

# log2
# 标准缩放（Standard Scaler）
#scaler = StandardScaler()
X_log2 = np.log2(X)
#X_log2 = X_log2.values.reshape(-1, 1)  # 将数据转换为二维数组
X_log2 = scaler.fit_transform(X_log2)
print(X_log2)
print()

# min-max (not accurate)(range set as[0,1])
min_max_scaler = preprocessing.MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(X)
print(X_minmax)
# Out:
# [[ 6.30439955e-02 -8.75943512e-01 -8.46053610e-01 ...  1.53020803e-03
#    1.47003114e-01 -1.19833988e+00]
#  [-5.89290461e-01 -8.05047199e-01 -5.36586734e-01 ...  1.13130343e+00
#   -1.27437229e+00  1.68915391e-01]
#  [-4.64322250e-01  2.48952115e-03 -2.73236052e-01 ...  1.14934039e+00
#    1.61797491e+00  1.69596708e+00]
#  ...
#  [-1.60190242e+00 -9.21991409e-01 -9.44154740e-01 ... -3.98991412e-01
#    1.73113416e-01  4.18283101e-01]
#  [-6.98806817e-01 -9.83024060e-01 -1.36151136e+00 ...  1.13993324e+00
#    1.23678209e+00  1.53489723e-01]
#  [-2.02496199e-01  3.51108556e-01 -9.79989889e-01 ... -8.38493747e-01
#    1.55948728e+00  3.54871711e-01]]
#
# [[ 0.33822219 -0.63803551 -0.59688348 ...  0.39178076  0.50412749
#   -1.22973405]
#  [-0.16730228 -0.54533591 -0.203795   ...  0.78054843 -1.50128803
#    0.52483595]
#  [-0.05305766  0.25408022  0.06199391 ...  0.78534113  1.02761095
#    1.05971924]
#  ...
#  [-2.07112796 -0.70114252 -0.7481936  ...  0.18210757  0.51725577
#    0.64161687]
#  [-0.27693515 -0.7886634  -1.67171559 ...  0.78284544  0.92193442
#    0.51699593]
#  [ 0.15666587  0.50758234 -0.8077432  ... -0.14999892  1.0122972
#    0.61355722]]
#
# [[0.60016212 0.33831183 0.27182377 ... 0.56785769 0.49199943 0.02710979]
#  [0.3841425  0.36160189 0.37736223 ... 0.98187655 0.01127753 0.47946592]
#  [0.42552555 0.6268847  0.46717355 ... 0.98848641 0.98949526 0.98469066]
#  ...
#  [0.04881751 0.3231847  0.23836803 ... 0.42108177 0.50083016 0.56196917]
#  [0.34787632 0.30313494 0.09603558 ... 0.98503905 0.86057244 0.47436234]
#  [0.51222887 0.74140907 0.22614705 ... 0.2600209  0.96971422 0.54098953]]

# %%
# split the data into train and test to verify accuracy after fitting 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, test_size = 0.3, random_state = 42)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# define classifier using the Boruta
import xgboost as xgb
model = xgb.XGBClassifier()
from boruta import BorutaPy
feat_selector = BorutaPy(model, n_estimators = 'auto', verbose = 2, random_state = 1)
feat_selector.fit(X_train, Y_train)

#  check the selected features
print(feat_selector.support_) # should we accept the feature or not
# check the ranking of the features
print(feat_selector.ranking_)
# filter down the selected features
X_filtered = feat_selector.transform(X_train)

# review the features
# zip feature names, ranks and decisions
feature_ranks = list(zip(feature_names, 
                         feat_selector.ranking_, 
                         feat_selector.support_))
cnt = 0
for feat in feature_ranks:
    if feat[2] == True:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        cnt += 1
print(cnt)


import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
from sklearn.tree import plot_tree
import numpy as np

forest = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
forest.fit(X_train, Y_train)
feature_importances = forest.feature_importances_
print(feature_importances)


# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]
non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]
# Print the top 10 feature importances
top_n = 10  # Change this to the desired number of top features to print
count = 0
for idx in non_zero_indices:
    if count < top_n:
        print(f"{feature_names[idx]}: {feature_importances[idx]}")
        count += 1
    else:
        break
        

# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]

non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]

# Select the top 10 feature indices
top_n = 10  # Change this to the desired number of top features to visualize
selected_indices = non_zero_indices[:top_n]

# Print the top 10 feature importances
for idx in selected_indices:
    print(f"{feature_names[idx]}: {feature_importances[idx]}")

# Visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_indices)), feature_importances[selected_indices])
plt.xticks(range(len(selected_indices)), [feature_names[i] for i in selected_indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Top 10 Feature Importances from RandomForestClassifier (Non-zero Importance)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	4966
# Iteration: 	9 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	10 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	11 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	12 / 100
# Confirmed: 	17
# Tentative: 	17
# Rejected: 	4966
# Iteration: 	13 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	14 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	15 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	13
# Rejected: 	4968
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	19 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	20 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	21 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	22 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	23 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	24 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	25 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	26 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	27 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	28 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	29 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	30 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	31 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	32 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	33 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	34 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	35 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	36 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	37 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	38 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	39 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	40 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	41 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	42 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	43 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	44 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	45 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	46 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	47 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	48 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	49 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	50 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	51 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	52 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	53 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	54 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	55 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	56 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	57 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	58 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	59 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
#
#
# BorutaPy finished running.
#
# Iteration: 	60 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
# [False False False ... False False False]
# [2495 2495 2495 ... 2495 2495 2495]
# Feature: cg00033551                     Rank: 1,  Keep: True
# Feature: cg00100680                     Rank: 1,  Keep: True
# Feature: cg01414185                     Rank: 1,  Keep: True
# Feature: cg03306374                     Rank: 1,  Keep: True
# Feature: cg07001508                     Rank: 1,  Keep: True
# Feature: cg08844913                     Rank: 1,  Keep: True
# Feature: cg13879483                     Rank: 1,  Keep: True
# Feature: cg14065127                     Rank: 1,  Keep: True
# Feature: cg14175690                     Rank: 1,  Keep: True
# Feature: cg14201387                     Rank: 1,  Keep: True
# Feature: cg14264159                     Rank: 1,  Keep: True
# Feature: cg14415956                     Rank: 1,  Keep: True
# Feature: cg14602220                     Rank: 1,  Keep: True
# Feature: cg20172627                     Rank: 1,  Keep: True
# Feature: cg20200460                     Rank: 1,  Keep: True
# Feature: cg20884887                     Rank: 1,  Keep: True
# Feature: cg21181756                     Rank: 1,  Keep: True
# Feature: cg21472506                     Rank: 1,  Keep: True
# Feature: cg22958090                     Rank: 1,  Keep: True
# Feature: cg24676071                     Rank: 1,  Keep: True
# Feature: cg24932457                     Rank: 1,  Keep: True
# Feature: cg26075742                     Rank: 1,  Keep: True
# Feature: cg26383138                     Rank: 1,  Keep: True
# Feature: cg26752576                     Rank: 1,  Keep: True
# Feature: cg27549186                     Rank: 1,  Keep: True
# Feature: rs1484127                      Rank: 1,  Keep: True
# Feature: rs5926356                      Rank: 1,  Keep: True
# 27
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#  0.00000000e+00 8.00533898e-18]
# cg24128045: 0.03185257831139414
# cg23498518: 0.022551276980074596
# cg22399133: 0.02215102131866003
# cg17400476: 0.018460163495654342
# cg07001508: 0.01715288646027037
# cg21042627: 0.015243415714421686
# cg16600501: 0.015196353370969685
# cg25863289: 0.015041732054261781
# cg06500727: 0.015007134518946008
# cg01782790: 0.014958108493664756
# cg24128045: 0.03185257831139414
# cg23498518: 0.022551276980074596
# cg22399133: 0.02215102131866003
# cg17400476: 0.018460163495654342
# cg07001508: 0.01715288646027037
# cg21042627: 0.015243415714421686
# cg16600501: 0.015196353370969685
# cg25863289: 0.015041732054261781
# cg06500727: 0.015007134518946008
# cg01782790: 0.014958108493664756

# %%
forest.fit(X_filtered, Y_train)

#Now predict on test data using the trained model. 

#First apply feature selector transform to make sure same features are selected from test data
X_test_filtered = feat_selector.transform(X_test)
prediction_forest = forest.predict(X_test_filtered)


#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(Y_test, prediction_forest))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, prediction_forest)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.9844961240310077
# <AxesSubplot:>

# %%
# log2
# 标准缩放（Standard Scaler）
#scaler = StandardScaler()
X_log2 = np.log2(X)
#X_log2 = X_log2.values.reshape(-1, 1)  # 将数据转换为二维数组
X_log2 = scaler.fit_transform(X_log2)
print(X_log2)
print()

# split the data into train and test to verify accuracy after fitting 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_log2, Y, test_size = 0.3, random_state = 42)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# define classifier using the Boruta
import xgboost as xgb
model = xgb. XGBClassifier()
from boruta import BorutaPy
feat_selector = BorutaPy(model, n_estimators = 'auto', verbose = 2, random_state = 1)
feat_selector.fit(X_train, Y_train)

#  check the selected features
print(feat_selector.support_) # should we accept the feature or not
# check the ranking of the features
print(feat_selector.ranking_)
# filter down the selected features
X_filtered = feat_selector.transform(X_train)

# review the features
# zip feature names, ranks and decisions
feature_ranks = list(zip(feature_names, 
                         feat_selector.ranking_, 
                         feat_selector.support_))
cnt = 0
for feat in feature_ranks:
    if feat[2] == True:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        cnt += 1
print(cnt)


import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
from sklearn.tree import plot_tree
import numpy as np

forest = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
forest.fit(X_train, Y_train)
feature_importances = forest.feature_importances_
print(feature_importances)


# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]
non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]
# Print the top 10 feature importances
top_n = 10  # Change this to the desired number of top features to print
count = 0
for idx in non_zero_indices:
    if count < top_n:
        print(f"{feature_names[idx]}: {feature_importances[idx]}")
        count += 1
    else:
        break
        

# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]

non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]

# Select the top 10 feature indices
top_n = 10  # Change this to the desired number of top features to visualize
selected_indices = non_zero_indices[:top_n]

# Print the top 10 feature importances
for idx in selected_indices:
    print(f"{feature_names[idx]}: {feature_importances[idx]}")

# Visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_indices)), feature_importances[selected_indices])
plt.xticks(range(len(selected_indices)), [feature_names[i] for i in selected_indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Top 10 Feature Importances from RandomForestClassifier (Non-zero Importance)")
plt.tight_layout()
plt.show()

forest.fit(X_filtered, Y_train)

#Now predict on test data using the trained model. 

#First apply feature selector transform to make sure same features are selected from test data
X_test_filtered = feat_selector.transform(X_test)
prediction_forest = forest.predict(X_test_filtered)


#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(Y_test, prediction_forest))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, prediction_forest)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[ 0.33822219 -0.63803551 -0.59688348 ...  0.39178076  0.50412749
#   -1.22973405]
#  [-0.16730228 -0.54533591 -0.203795   ...  0.78054843 -1.50128803
#    0.52483595]
#  [-0.05305766  0.25408022  0.06199391 ...  0.78534113  1.02761095
#    1.05971924]
#  ...
#  [-2.07112796 -0.70114252 -0.7481936  ...  0.18210757  0.51725577
#    0.64161687]
#  [-0.27693515 -0.7886634  -1.67171559 ...  0.78284544  0.92193442
#    0.51699593]
#  [ 0.15666587  0.50758234 -0.8077432  ... -0.14999892  1.0122972
#    0.61355722]]
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	4966
# Iteration: 	9 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	10 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	11 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	12 / 100
# Confirmed: 	17
# Tentative: 	17
# Rejected: 	4966
# Iteration: 	13 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	14 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	15 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	13
# Rejected: 	4968
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	19 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	20 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	21 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	22 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	23 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	24 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	25 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	26 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	27 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	28 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	29 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	30 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	31 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	32 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	33 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	34 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	35 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	36 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	37 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	38 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	39 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	40 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	41 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	42 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	43 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	44 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	45 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	46 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	47 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	48 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	49 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	50 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	51 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	52 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	53 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	54 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	55 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	56 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	57 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	58 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	59 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
#
#
# BorutaPy finished running.
#
# Iteration: 	60 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
# [False False False ... False False False]
# [2495 2495 2495 ... 2495 2495 2495]
# Feature: cg00033551                     Rank: 1,  Keep: True
# Feature: cg00100680                     Rank: 1,  Keep: True
# Feature: cg01414185                     Rank: 1,  Keep: True
# Feature: cg03306374                     Rank: 1,  Keep: True
# Feature: cg07001508                     Rank: 1,  Keep: True
# Feature: cg08844913                     Rank: 1,  Keep: True
# Feature: cg13879483                     Rank: 1,  Keep: True
# Feature: cg14065127                     Rank: 1,  Keep: True
# Feature: cg14175690                     Rank: 1,  Keep: True
# Feature: cg14201387                     Rank: 1,  Keep: True
# Feature: cg14264159                     Rank: 1,  Keep: True
# Feature: cg14415956                     Rank: 1,  Keep: True
# Feature: cg14602220                     Rank: 1,  Keep: True
# Feature: cg20172627                     Rank: 1,  Keep: True
# Feature: cg20200460                     Rank: 1,  Keep: True
# Feature: cg20884887                     Rank: 1,  Keep: True
# Feature: cg21181756                     Rank: 1,  Keep: True
# Feature: cg21472506                     Rank: 1,  Keep: True
# Feature: cg22958090                     Rank: 1,  Keep: True
# Feature: cg24676071                     Rank: 1,  Keep: True
# Feature: cg24932457                     Rank: 1,  Keep: True
# Feature: cg26075742                     Rank: 1,  Keep: True
# Feature: cg26383138                     Rank: 1,  Keep: True
# Feature: cg26752576                     Rank: 1,  Keep: True
# Feature: cg27549186                     Rank: 1,  Keep: True
# Feature: rs1484127                      Rank: 1,  Keep: True
# Feature: rs5926356                      Rank: 1,  Keep: True
# 27
# [0.00000000e+00 1.55624458e-17 0.00000000e+00 ... 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# cg24833737: 0.026468806870705547
# cg21472506: 0.019381532118306885
# cg27573735: 0.016416637978481027
# cg07001508: 0.01577590584002916
# cg10256733: 0.015474076743768918
# cg02096296: 0.01470522338827689
# cg01221209: 0.01468616370381524
# cg12584111: 0.014635478294029914
# cg19813015: 0.014210659063618876
# cg05762221: 0.01416535483659031
# cg24833737: 0.026468806870705547
# cg21472506: 0.019381532118306885
# cg27573735: 0.016416637978481027
# cg07001508: 0.01577590584002916
# cg10256733: 0.015474076743768918
# cg02096296: 0.01470522338827689
# cg01221209: 0.01468616370381524
# cg12584111: 0.014635478294029914
# cg19813015: 0.014210659063618876
# cg05762221: 0.01416535483659031
# Accuracy =  0.9844961240310077
# <AxesSubplot:>

# %%
# min-max (not accurate)(range set as[0,1])
min_max_scaler = preprocessing.MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(X)
print(X_minmax)

# split the data into train and test to verify accuracy after fitting 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_minmax, Y, test_size = 0.3, random_state = 42)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# define classifier using the Boruta
import xgboost as xgb
model = xgb. XGBClassifier()
from boruta import BorutaPy
feat_selector = BorutaPy(model, n_estimators = 'auto', verbose = 2, random_state = 1)
feat_selector.fit(X_train, Y_train)

#  check the selected features
print(feat_selector.support_) # should we accept the feature or not
# check the ranking of the features
print(feat_selector.ranking_)
# filter down the selected features
X_filtered = feat_selector.transform(X_train)

# review the features
# zip feature names, ranks and decisions
feature_ranks = list(zip(feature_names, 
                         feat_selector.ranking_, 
                         feat_selector.support_))
cnt = 0
for feat in feature_ranks:
    if feat[2] == True:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        cnt += 1
print(cnt)


import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
from sklearn.tree import plot_tree
import numpy as np

forest = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
forest.fit(X_train, Y_train)
feature_importances = forest.feature_importances_
print(feature_importances)


# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]
non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]
# Print the top 10 feature importances
top_n = 10  # Change this to the desired number of top features to print
count = 0
for idx in non_zero_indices:
    if count < top_n:
        print(f"{feature_names[idx]}: {feature_importances[idx]}")
        count += 1
    else:
        break
        

# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]

non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]

# Select the top 10 feature indices
top_n = 10  # Change this to the desired number of top features to visualize
selected_indices = non_zero_indices[:top_n]

# Print the top 10 feature importances
for idx in selected_indices:
    print(f"{feature_names[idx]}: {feature_importances[idx]}")

# Visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_indices)), feature_importances[selected_indices])
plt.xticks(range(len(selected_indices)), [feature_names[i] for i in selected_indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Top 10 Feature Importances from RandomForestClassifier (Non-zero Importance)")
plt.tight_layout()
plt.show()

forest.fit(X_filtered, Y_train)

#Now predict on test data using the trained model. 

#First apply feature selector transform to make sure same features are selected from test data
X_test_filtered = feat_selector.transform(X_test)
prediction_forest = forest.predict(X_test_filtered)


#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(Y_test, prediction_forest))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, prediction_forest)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[0.60016212 0.33831183 0.27182377 ... 0.56785769 0.49199943 0.02710979]
#  [0.3841425  0.36160189 0.37736223 ... 0.98187655 0.01127753 0.47946592]
#  [0.42552555 0.6268847  0.46717355 ... 0.98848641 0.98949526 0.98469066]
#  ...
#  [0.04881751 0.3231847  0.23836803 ... 0.42108177 0.50083016 0.56196917]
#  [0.34787632 0.30313494 0.09603558 ... 0.98503905 0.86057244 0.47436234]
#  [0.51222887 0.74140907 0.22614705 ... 0.2600209  0.96971422 0.54098953]]
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Minyan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	5000
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	34
# Rejected: 	4966
# Iteration: 	9 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	10 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	11 / 100
# Confirmed: 	11
# Tentative: 	23
# Rejected: 	4966
# Iteration: 	12 / 100
# Confirmed: 	17
# Tentative: 	17
# Rejected: 	4966
# Iteration: 	13 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	14 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	15 / 100
# Confirmed: 	17
# Tentative: 	15
# Rejected: 	4968
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	13
# Rejected: 	4968
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	12
# Rejected: 	4969
# Iteration: 	19 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	20 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	21 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	22 / 100
# Confirmed: 	20
# Tentative: 	11
# Rejected: 	4969
# Iteration: 	23 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	24 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	25 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	4970
# Iteration: 	26 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	27 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	28 / 100
# Confirmed: 	22
# Tentative: 	8
# Rejected: 	4970
# Iteration: 	29 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	30 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	31 / 100
# Confirmed: 	23
# Tentative: 	6
# Rejected: 	4971
# Iteration: 	32 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	33 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	34 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	35 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	36 / 100
# Confirmed: 	25
# Tentative: 	4
# Rejected: 	4971
# Iteration: 	37 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	38 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	39 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	40 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	41 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	42 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	43 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	44 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	45 / 100
# Confirmed: 	26
# Tentative: 	3
# Rejected: 	4971
# Iteration: 	46 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	47 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	48 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	49 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	50 / 100
# Confirmed: 	26
# Tentative: 	2
# Rejected: 	4972
# Iteration: 	51 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	52 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	53 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	54 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	55 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	56 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	57 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	58 / 100
# Confirmed: 	26
# Tentative: 	1
# Rejected: 	4973
# Iteration: 	59 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
#
#
# BorutaPy finished running.
#
# Iteration: 	60 / 100
# Confirmed: 	27
# Tentative: 	0
# Rejected: 	4973
# [False False False ... False False False]
# [2495 2495 2495 ... 2495 2495 2495]
# Feature: cg00033551                     Rank: 1,  Keep: True
# Feature: cg00100680                     Rank: 1,  Keep: True
# Feature: cg01414185                     Rank: 1,  Keep: True
# Feature: cg03306374                     Rank: 1,  Keep: True
# Feature: cg07001508                     Rank: 1,  Keep: True
# Feature: cg08844913                     Rank: 1,  Keep: True
# Feature: cg13879483                     Rank: 1,  Keep: True
# Feature: cg14065127                     Rank: 1,  Keep: True
# Feature: cg14175690                     Rank: 1,  Keep: True
# Feature: cg14201387                     Rank: 1,  Keep: True
# Feature: cg14264159                     Rank: 1,  Keep: True
# Feature: cg14415956                     Rank: 1,  Keep: True
# Feature: cg14602220                     Rank: 1,  Keep: True
# Feature: cg20172627                     Rank: 1,  Keep: True
# Feature: cg20200460                     Rank: 1,  Keep: True
# Feature: cg20884887                     Rank: 1,  Keep: True
# Feature: cg21181756                     Rank: 1,  Keep: True
# Feature: cg21472506                     Rank: 1,  Keep: True
# Feature: cg22958090                     Rank: 1,  Keep: True
# Feature: cg24676071                     Rank: 1,  Keep: True
# Feature: cg24932457                     Rank: 1,  Keep: True
# Feature: cg26075742                     Rank: 1,  Keep: True
# Feature: cg26383138                     Rank: 1,  Keep: True
# Feature: cg26752576                     Rank: 1,  Keep: True
# Feature: cg27549186                     Rank: 1,  Keep: True
# Feature: rs1484127                      Rank: 1,  Keep: True
# Feature: rs5926356                      Rank: 1,  Keep: True
# 27
# [0. 0. 0. ... 0. 0. 0.]
# cg26075742: 0.02419318679496329
# cg00417291: 0.02284125028893099
# cg06500727: 0.02173989073428283
# cg14644001: 0.01848463163810265
# cg22524061: 0.017648464357468786
# cg24563094: 0.017246846064401952
# cg26752576: 0.015956482985676503
# cg14958969: 0.015821283876641015
# cg16600501: 0.01526497765786873
# cg10256733: 0.015243365841492084
# cg26075742: 0.02419318679496329
# cg00417291: 0.02284125028893099
# cg06500727: 0.02173989073428283
# cg14644001: 0.01848463163810265
# cg22524061: 0.017648464357468786
# cg24563094: 0.017246846064401952
# cg26752576: 0.015956482985676503
# cg14958969: 0.015821283876641015
# cg16600501: 0.01526497765786873
# cg10256733: 0.015243365841492084
# Accuracy =  0.9844961240310077
# <AxesSubplot:>
