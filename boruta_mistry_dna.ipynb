# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_dna = pd.read_csv("mystery_dna-meth.csv")
df_dna
# Out:
#           Unnamed: 0                Label  cg00001583  cg00001747  cg00002719  \
# 0    TCGA.C8.A274.01        Primary Tumor    0.776662    0.809844    0.891880
# 1    TCGA.E2.A572.01        Primary Tumor    0.669769    0.029292    0.761326
# 2    TCGA.AO.A0JA.01        Primary Tumor    0.505964    0.525509    0.806467
# 3    TCGA.E2.A1BD.01        Primary Tumor    0.814448    0.814974    0.902881
# 4    TCGA.AC.A5EH.01        Primary Tumor    0.418687    0.031154    0.449726
# ..               ...                  ...         ...         ...         ...
# 375  TCGA.18.5595.11  Solid Tissue Normal         NaN    0.020024    0.019219
# 376  TCGA.39.5036.11  Solid Tissue Normal         NaN    0.037856    0.019365
# 377  TCGA.22.5492.11  Solid Tissue Normal         NaN    0.017807    0.024142
# 378  TCGA.22.5477.11  Solid Tissue Normal         NaN    0.029362    0.016582
# 379  TCGA.33.4582.11  Solid Tissue Normal         NaN    0.013574    0.021197
#
#      cg00011616  cg00013655  cg00025347  cg00034076  cg00036011  ...  \
# 0      0.328564    0.849209    0.235096    0.714533    0.048083  ...
# 1      0.188135    0.830146    0.308065    0.742329    0.413321  ...
# 2      0.940331    0.711453    0.328805    0.155193    0.031138  ...
# 3      0.069385    0.927201    0.225843    0.794465    0.766701  ...
# 4      0.160170    0.617900    0.605715    0.076246    0.067412  ...
# ..          ...         ...         ...         ...         ...  ...
# 375    0.580281         NaN         NaN    0.062250         NaN  ...
# 376    0.479544         NaN         NaN    0.094240         NaN  ...
# 377    0.301080         NaN         NaN    0.098974         NaN  ...
# 378    0.497647         NaN         NaN    0.082672         NaN  ...
# 379    0.343380         NaN         NaN    0.051354         NaN  ...
#
#      cg27527798  cg27538352  cg27539986  cg27546977  cg27553926  cg27583037  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 375    0.807542    0.977556    0.143700    0.130896    0.065430    0.034557
# 376    0.840923    0.978938    0.082066    0.113188    0.099127    0.049164
# 377    0.829504    0.980464    0.098895    0.198826    0.081321    0.024921
# 378    0.884962    0.971747    0.081415    0.148806    0.113125    0.044641
# 379    0.883188    0.981858    0.098270    0.105638    0.131887    0.023997
#
#      cg27592331  cg27623451  cg27633287  cg27649037
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 375    0.269848    0.962175    0.930841    0.973963
# 376    0.342877    0.949303    0.659989    0.980929
# 377    0.190175    0.956378    0.942248    0.972996
# 378    0.331803    0.953369    0.897109    0.970955
# 379    0.236978    0.953326    0.841366    0.979265
#
# [380 rows x 18093 columns]

# %%
counts = []
cnt = 0
for i,row in enumerate(df_dna):
    for j, row in enumerate(df_dna):
        if (i,j) == "NaN"
            cnt  += 1
            print(cnt)
    
#print(f"Row {i + 1}: {count}个0")
# Out:
#   File "C:\Users\Minyan\AppData\Local\Temp\ipykernel_17820\1951927821.py", line 5
#     if (i,j) == "NaN"
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# 假设你已经有一个名为df_dna的DataFrame

# 使用isna()方法检查每一列中的NaN值，并使用sum()方法计算每一列的NaN数量
nan_counts = df_dna.isna().sum()

# 打印每一列的NaN数量
print(nan_counts)
# Out:
# Unnamed: 0      0
# Label           0
# cg00001583    304
# cg00001747    228
# cg00002719    152
#              ...
# cg27583037    304
# cg27592331    304
# cg27623451    304
# cg27633287    304
# cg27649037    304
# Length: 18093, dtype: int64

# %%
df_dna.info()
df_dna.isna().head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 18093 entries, Unnamed: 0 to cg27649037
# dtypes: float64(18091), object(2)
# memory usage: 52.5+ MB
#    Unnamed: 0  Label  cg00001583  cg00001747  cg00002719  cg00011616  \
# 0       False  False       False       False       False       False
# 1       False  False       False       False       False       False
# 2       False  False       False       False       False       False
# 3       False  False       False       False       False       False
# 4       False  False       False       False       False       False
#
#    cg00013655  cg00025347  cg00034076  cg00036011  ...  cg27527798  \
# 0       False       False       False       False  ...        True
# 1       False       False       False       False  ...        True
# 2       False       False       False       False  ...        True
# 3       False       False       False       False  ...        True
# 4       False       False       False       False  ...        True
#
#    cg27538352  cg27539986  cg27546977  cg27553926  cg27583037  cg27592331  \
# 0        True        True        True        True        True        True
# 1        True        True        True        True        True        True
# 2        True        True        True        True        True        True
# 3        True        True        True        True        True        True
# 4        True        True        True        True        True        True
#
#    cg27623451  cg27633287  cg27649037
# 0        True        True        True
# 1        True        True        True
# 2        True        True        True
# 3        True        True        True
# 4        True        True        True
#
# [5 rows x 18093 columns]

# %%
type(df_dna)
# Out:
# pandas.core.frame.DataFrame

# %%
# rename the dataset to label
unique_labels = df_dna.iloc[:, 1].unique()

# print the name of the classification
for label in unique_labels:
    print(label)
    
df_dna = df_dna.rename(columns = {'Primary Tumor':'0'})
df_dna
# Out:
# Primary Tumor
# Solid Tissue Normal
#           Unnamed: 0                Label  cg00001583  cg00001747  cg00002719  \
# 0    TCGA.C8.A274.01        Primary Tumor    0.776662    0.809844    0.891880
# 1    TCGA.E2.A572.01        Primary Tumor    0.669769    0.029292    0.761326
# 2    TCGA.AO.A0JA.01        Primary Tumor    0.505964    0.525509    0.806467
# 3    TCGA.E2.A1BD.01        Primary Tumor    0.814448    0.814974    0.902881
# 4    TCGA.AC.A5EH.01        Primary Tumor    0.418687    0.031154    0.449726
# ..               ...                  ...         ...         ...         ...
# 375  TCGA.18.5595.11  Solid Tissue Normal         NaN    0.020024    0.019219
# 376  TCGA.39.5036.11  Solid Tissue Normal         NaN    0.037856    0.019365
# 377  TCGA.22.5492.11  Solid Tissue Normal         NaN    0.017807    0.024142
# 378  TCGA.22.5477.11  Solid Tissue Normal         NaN    0.029362    0.016582
# 379  TCGA.33.4582.11  Solid Tissue Normal         NaN    0.013574    0.021197
#
#      cg00011616  cg00013655  cg00025347  cg00034076  cg00036011  ...  \
# 0      0.328564    0.849209    0.235096    0.714533    0.048083  ...
# 1      0.188135    0.830146    0.308065    0.742329    0.413321  ...
# 2      0.940331    0.711453    0.328805    0.155193    0.031138  ...
# 3      0.069385    0.927201    0.225843    0.794465    0.766701  ...
# 4      0.160170    0.617900    0.605715    0.076246    0.067412  ...
# ..          ...         ...         ...         ...         ...  ...
# 375    0.580281         NaN         NaN    0.062250         NaN  ...
# 376    0.479544         NaN         NaN    0.094240         NaN  ...
# 377    0.301080         NaN         NaN    0.098974         NaN  ...
# 378    0.497647         NaN         NaN    0.082672         NaN  ...
# 379    0.343380         NaN         NaN    0.051354         NaN  ...
#
#      cg27527798  cg27538352  cg27539986  cg27546977  cg27553926  cg27583037  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 375    0.807542    0.977556    0.143700    0.130896    0.065430    0.034557
# 376    0.840923    0.978938    0.082066    0.113188    0.099127    0.049164
# 377    0.829504    0.980464    0.098895    0.198826    0.081321    0.024921
# 378    0.884962    0.971747    0.081415    0.148806    0.113125    0.044641
# 379    0.883188    0.981858    0.098270    0.105638    0.131887    0.023997
#
#      cg27592331  cg27623451  cg27633287  cg27649037
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 375    0.269848    0.962175    0.930841    0.973963
# 376    0.342877    0.949303    0.659989    0.980929
# 377    0.190175    0.956378    0.942248    0.972996
# 378    0.331803    0.953369    0.897109    0.970955
# 379    0.236978    0.953326    0.841366    0.979265
#
# [380 rows x 18093 columns]

# %%
df_dna['Label'].value_counts()
# Out:
# Primary Tumor          190
# Solid Tissue Normal    190
# Name: Label, dtype: int64

# %%
# define the dependt variable that need to be predicted 
y = df_dna['Label'].values

# encoding catergorical data
from sklearn.preprocessing import LabelEncoder
Labelencoder = LabelEncoder()
Y = Labelencoder.fit_transform(y) # Primary Tumor = 0, Solid Tissue Normal = 1

# %%
# define x and normalization
# Define the independent variables to drop the Label and Unnamed: 0
X = df_dna.drop(labels = ['Label','Unnamed: 0'], axis = 1)

import numpy as np
feature_names = np.array(X.columns)

# %%
X = X.fillna(0.000001)
print("替换后的 DataFrame：")
print(X)
# Out:
# 替换后的 DataFrame：
#      cg00001583  cg00001747  cg00002719  cg00011616  cg00013655  cg00025347  \
# 0      0.776662    0.809844    0.891880    0.328564    0.849209    0.235096
# 1      0.669769    0.029292    0.761326    0.188135    0.830146    0.308065
# 2      0.505964    0.525509    0.806467    0.940331    0.711453    0.328805
# 3      0.814448    0.814974    0.902881    0.069385    0.927201    0.225843
# 4      0.418687    0.031154    0.449726    0.160170    0.617900    0.605715
# ..          ...         ...         ...         ...         ...         ...
# 375    0.010000    0.020024    0.019219    0.580281    0.010000    0.010000
# 376    0.010000    0.037856    0.019365    0.479544    0.010000    0.010000
# 377    0.010000    0.017807    0.024142    0.301080    0.010000    0.010000
# 378    0.010000    0.029362    0.016582    0.497647    0.010000    0.010000
# 379    0.010000    0.013574    0.021197    0.343380    0.010000    0.010000
#
#      cg00034076  cg00036011  cg00041599  cg00043510  ...  cg27527798  \
# 0      0.714533    0.048083    0.789195    0.843541  ...    0.010000
# 1      0.742329    0.413321    0.780104    0.389220  ...    0.010000
# 2      0.155193    0.031138    0.690710    0.906576  ...    0.010000
# 3      0.794465    0.766701    0.583945    0.889449  ...    0.010000
# 4      0.076246    0.067412    0.729701    0.664980  ...    0.010000
# ..          ...         ...         ...         ...  ...         ...
# 375    0.062250    0.010000    0.010000    0.099164  ...    0.807542
# 376    0.094240    0.010000    0.010000    0.121330  ...    0.840923
# 377    0.098974    0.010000    0.010000    0.098162  ...    0.829504
# 378    0.082672    0.010000    0.010000    0.081430  ...    0.884962
# 379    0.051354    0.010000    0.010000    0.089761  ...    0.883188
#
#      cg27538352  cg27539986  cg27546977  cg27553926  cg27583037  cg27592331  \
# 0      0.010000    0.010000    0.010000    0.010000    0.010000    0.010000
# 1      0.010000    0.010000    0.010000    0.010000    0.010000    0.010000
# 2      0.010000    0.010000    0.010000    0.010000    0.010000    0.010000
# 3      0.010000    0.010000    0.010000    0.010000    0.010000    0.010000
# 4      0.010000    0.010000    0.010000    0.010000    0.010000    0.010000
# ..          ...         ...         ...         ...         ...         ...
# 375    0.977556    0.143700    0.130896    0.065430    0.034557    0.269848
# 376    0.978938    0.082066    0.113188    0.099127    0.049164    0.342877
# 377    0.980464    0.098895    0.198826    0.081321    0.024921    0.190175
# 378    0.971747    0.081415    0.148806    0.113125    0.044641    0.331803
# 379    0.981858    0.098270    0.105638    0.131887    0.023997    0.236978
#
#      cg27623451  cg27633287  cg27649037
# 0      0.010000    0.010000    0.010000
# 1      0.010000    0.010000    0.010000
# 2      0.010000    0.010000    0.010000
# 3      0.010000    0.010000    0.010000
# 4      0.010000    0.010000    0.010000
# ..          ...         ...         ...
# 375    0.962175    0.930841    0.973963
# 376    0.949303    0.659989    0.980929
# 377    0.956378    0.942248    0.972996
# 378    0.953369    0.897109    0.970955
# 379    0.953326    0.841366    0.979265
#
# [380 rows x 18091 columns]

# %%
# normalization
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
scaler.fit(X)
# log2
# 标准缩放（Standard Scaler）
#scaler = StandardScaler()
X_log2 = np.log2(X)
#X_log2 = X_log2.values.reshape(-1, 1)  # 将数据转换为二维数组
#X_log2 = scaler.fit_transform(X_log2)
print(X_log2)
print()
# Out:
#      cg00001583  cg00001747  cg00002719  cg00011616  cg00013655  cg00025347  \
# 0     -0.364641   -0.304284   -0.165079   -1.605755   -0.235808   -2.088681
# 1     -0.578264   -5.093354   -0.393413   -2.410163   -0.268564   -1.698693
# 2     -0.982893   -0.928213   -0.310313   -0.088760   -0.491160   -1.604697
# 3     -0.296106   -0.295175   -0.147392   -3.849239   -0.109046   -2.146605
# 4     -1.256058   -5.004460   -1.152882   -2.642322   -0.694554   -0.723289
# ..          ...         ...         ...         ...         ...         ...
# 375   -6.643856   -5.642134   -5.701312   -0.785176   -6.643856   -6.643856
# 376   -6.643856   -4.723346   -5.690413   -1.060264   -6.643856   -6.643856
# 377   -6.643856   -5.811376   -5.372327   -1.731780   -6.643856   -6.643856
# 378   -6.643856   -5.089919   -5.914216   -1.006807   -6.643856   -6.643856
# 379   -6.643856   -6.202957   -5.559987   -1.542120   -6.643856   -6.643856
#
#      cg00034076  cg00036011  cg00041599  cg00043510  ...  cg27527798  \
# 0     -0.484928   -4.378332   -0.341547   -0.245470  ...   -6.643856
# 1     -0.429868   -1.274665   -0.358262   -1.361344  ...   -6.643856
# 2     -2.687866   -5.005201   -0.533848   -0.141500  ...   -6.643856
# 3     -0.331945   -0.383264   -0.776097   -0.169016  ...   -6.643856
# 4     -3.713191   -3.890852   -0.454623   -0.588616  ...   -6.643856
# ..          ...         ...         ...         ...  ...         ...
# 375   -4.005782   -6.643856   -6.643856   -3.334037  ...   -0.308391
# 376   -3.407514   -6.643856   -6.643856   -3.042992  ...   -0.249955
# 377   -3.336803   -6.643856   -6.643856   -3.348698  ...   -0.269678
# 378   -3.596461   -6.643856   -6.643856   -3.618294  ...   -0.176312
# 379   -4.283372   -6.643856   -6.643856   -3.477773  ...   -0.179207
#
#      cg27538352  cg27539986  cg27546977  cg27553926  cg27583037  cg27592331  \
# 0     -6.643856   -6.643856   -6.643856   -6.643856   -6.643856   -6.643856
# 1     -6.643856   -6.643856   -6.643856   -6.643856   -6.643856   -6.643856
# 2     -6.643856   -6.643856   -6.643856   -6.643856   -6.643856   -6.643856
# 3     -6.643856   -6.643856   -6.643856   -6.643856   -6.643856   -6.643856
# 4     -6.643856   -6.643856   -6.643856   -6.643856   -6.643856   -6.643856
# ..          ...         ...         ...         ...         ...         ...
# 375   -0.032748   -2.798864   -2.933510   -3.933901   -4.854861   -1.889782
# 376   -0.030711   -3.607076   -3.143211   -3.334581   -4.346249   -1.544235
# 377   -0.028464   -3.337962   -2.330425   -3.620233   -5.326480   -2.394601
# 378   -0.041348   -3.618561   -2.748494   -3.144004   -4.485480   -1.591601
# 379   -0.026414   -3.347102   -3.242795   -2.922628   -5.381018   -2.077174
#
#      cg27623451  cg27633287  cg27649037
# 0     -6.643856   -6.643856   -6.643856
# 1     -6.643856   -6.643856   -6.643856
# 2     -6.643856   -6.643856   -6.643856
# 3     -6.643856   -6.643856   -6.643856
# 4     -6.643856   -6.643856   -6.643856
# ..          ...         ...         ...
# 375   -0.055629   -0.103393   -0.038061
# 376   -0.075060   -0.599486   -0.027779
# 377   -0.064347   -0.085821   -0.039494
# 378   -0.068894   -0.156645   -0.042524
# 379   -0.068958   -0.249194   -0.030229
#
# [380 rows x 18091 columns]

# %%
# split the data into train and test to verify accuracy after fitting 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_log2, Y, test_size = 0.3, random_state = 42)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# define classifier using the Boruta
import xgboost as xgb
model = xgb. XGBClassifier()
from boruta import BorutaPy
feat_selector = BorutaPy(model, n_estimators = 'auto', verbose = 2, random_state = 1)
feat_selector.fit(X_train, Y_train)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	18091
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	18027
# Iteration: 	9 / 100
# Confirmed: 	17
# Tentative: 	47
# Rejected: 	18027
# Iteration: 	10 / 100
# Confirmed: 	17
# Tentative: 	47
# Rejected: 	18027
# Iteration: 	11 / 100
# Confirmed: 	17
# Tentative: 	47
# Rejected: 	18027
# Iteration: 	12 / 100
# Confirmed: 	29
# Tentative: 	21
# Rejected: 	18041
# Iteration: 	13 / 100
# Confirmed: 	29
# Tentative: 	21
# Rejected: 	18041
# Iteration: 	14 / 100
# Confirmed: 	29
# Tentative: 	21
# Rejected: 	18041
# Iteration: 	15 / 100
# Confirmed: 	29
# Tentative: 	21
# Rejected: 	18041
# Iteration: 	16 / 100
# Confirmed: 	30
# Tentative: 	17
# Rejected: 	18044
# Iteration: 	17 / 100
# Confirmed: 	30
# Tentative: 	17
# Rejected: 	18044
# Iteration: 	18 / 100
# Confirmed: 	30
# Tentative: 	17
# Rejected: 	18044
# Iteration: 	19 / 100
# Confirmed: 	30
# Tentative: 	17
# Rejected: 	18044
# Iteration: 	20 / 100
# Confirmed: 	30
# Tentative: 	15
# Rejected: 	18046
# Iteration: 	21 / 100
# Confirmed: 	30
# Tentative: 	15
# Rejected: 	18046
# Iteration: 	22 / 100
# Confirmed: 	31
# Tentative: 	11
# Rejected: 	18049
# Iteration: 	23 / 100
# Confirmed: 	31
# Tentative: 	11
# Rejected: 	18049
# Iteration: 	24 / 100
# Confirmed: 	31
# Tentative: 	11
# Rejected: 	18049
# Iteration: 	25 / 100
# Confirmed: 	31
# Tentative: 	11
# Rejected: 	18049
# Iteration: 	26 / 100
# Confirmed: 	37
# Tentative: 	5
# Rejected: 	18049
# Iteration: 	27 / 100
# Confirmed: 	37
# Tentative: 	5
# Rejected: 	18049
# Iteration: 	28 / 100
# Confirmed: 	37
# Tentative: 	5
# Rejected: 	18049
# Iteration: 	29 / 100
# Confirmed: 	38
# Tentative: 	4
# Rejected: 	18049
# Iteration: 	30 / 100
# Confirmed: 	38
# Tentative: 	4
# Rejected: 	18049
# Iteration: 	31 / 100
# Confirmed: 	38
# Tentative: 	4
# Rejected: 	18049
# Iteration: 	32 / 100
# Confirmed: 	40
# Tentative: 	2
# Rejected: 	18049
# Iteration: 	33 / 100
# Confirmed: 	40
# Tentative: 	2
# Rejected: 	18049
# Iteration: 	34 / 100
# Confirmed: 	40
# Tentative: 	2
# Rejected: 	18049
# Iteration: 	35 / 100
# Confirmed: 	40
# Tentative: 	2
# Rejected: 	18049
# Iteration: 	36 / 100
# Confirmed: 	40
# Tentative: 	2
# Rejected: 	18049
# Iteration: 	37 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	38 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	39 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	40 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	41 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	42 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	43 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	44 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	45 / 100
# Confirmed: 	41
# Tentative: 	1
# Rejected: 	18049
# Iteration: 	46 / 100
# Confirmed: 	42
# Tentative: 	0
# Rejected: 	18049
#
#
# BorutaPy finished running.
#
# Iteration: 	47 / 100
# Confirmed: 	42
# Tentative: 	0
# Rejected: 	18049
# BorutaPy(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                  colsample_bylevel=None, colsample_bynode=None,
#                                  colsample_bytree=None,
#                                  early_stopping_rounds=None,
#                                  enable_categorical=False, eval_metric=None,
#                                  feature_types=None, gamma=None, gpu_id=None,
#                                  grow_policy=None, importance_type=None,
#                                  interaction_constraints=None,
#                                  learning_rate=None, max_bin=None,
#                                  max_cat_threshold=None, max_cat_to_onehot=None,
#                                  max_delta_step=None, max_depth=None,
#                                  max_leaves=None, min_child_weight=None,
#                                  missing=nan, monotone_constraints=None,
#                                  n_estimators=91, n_jobs=None,
#                                  num_parallel_tree=None, predictor=None,
#                                  random_state=2050261805, ...),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x1F701967C40, verbose=2)

# %%
#  check the selected features
print(feat_selector.support_) # should we accept the feature or not
# check the ranking of the features
print(feat_selector.ranking_)
# filter down the selected features
X_filtered = feat_selector.transform(X_train)
# Out:
# [False False False ... False False False]
# [9042 9042 9042 ... 9042 9042 9042]

# %%
# review the features
# zip feature names, ranks and decisions
feature_ranks = list(zip(feature_names, 
                         feat_selector.ranking_, 
                         feat_selector.support_))
cnt = 0
for feat in feature_ranks:
    if feat[2] == True:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        cnt += 1
print(cnt)
# Out:
# Feature: cg00106345                     Rank: 1,  Keep: True
# Feature: cg00186815                     Rank: 1,  Keep: True
# Feature: cg00674365                     Rank: 1,  Keep: True
# Feature: cg00931644                     Rank: 1,  Keep: True
# Feature: cg01176363                     Rank: 1,  Keep: True
# Feature: cg02349416                     Rank: 1,  Keep: True
# Feature: cg03580872                     Rank: 1,  Keep: True
# Feature: cg05422029                     Rank: 1,  Keep: True
# Feature: cg05735180                     Rank: 1,  Keep: True
# Feature: cg05970721                     Rank: 1,  Keep: True
# Feature: cg07149609                     Rank: 1,  Keep: True
# Feature: cg09170112                     Rank: 1,  Keep: True
# Feature: cg09489306                     Rank: 1,  Keep: True
# Feature: cg11157172                     Rank: 1,  Keep: True
# Feature: cg11823511                     Rank: 1,  Keep: True
# Feature: cg11957331                     Rank: 1,  Keep: True
# Feature: cg13246235                     Rank: 1,  Keep: True
# Feature: cg13445796                     Rank: 1,  Keep: True
# Feature: cg13547712                     Rank: 1,  Keep: True
# Feature: cg13879483                     Rank: 1,  Keep: True
# Feature: cg15811515                     Rank: 1,  Keep: True
# Feature: cg15848890                     Rank: 1,  Keep: True
# Feature: cg16288089                     Rank: 1,  Keep: True
# Feature: cg16647921                     Rank: 1,  Keep: True
# Feature: cg17840719                     Rank: 1,  Keep: True
# Feature: cg18322569                     Rank: 1,  Keep: True
# Feature: cg18450582                     Rank: 1,  Keep: True
# Feature: cg20042908                     Rank: 1,  Keep: True
# Feature: cg21472506                     Rank: 1,  Keep: True
# Feature: cg21769093                     Rank: 1,  Keep: True
# Feature: cg24833737                     Rank: 1,  Keep: True
# Feature: cg25446076                     Rank: 1,  Keep: True
# Feature: cg25570913                     Rank: 1,  Keep: True
# Feature: cg25968569                     Rank: 1,  Keep: True
# Feature: rs3936238                      Rank: 1,  Keep: True
# Feature: cg19779965                     Rank: 1,  Keep: True
# Feature: cg24879782                     Rank: 1,  Keep: True
# Feature: cg26010734                     Rank: 1,  Keep: True
# Feature: cg00009553                     Rank: 1,  Keep: True
# Feature: cg07533148                     Rank: 1,  Keep: True
# Feature: cg15564098                     Rank: 1,  Keep: True
# Feature: cg19811337                     Rank: 1,  Keep: True
# 42

# %%
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
from sklearn.tree import plot_tree
import numpy as np

forest = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
forest.fit(X_train, Y_train)
feature_importances = forest.feature_importances_
print(feature_importances)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]
non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]
# Print the top 10 feature importances
top_n = 10  # Change this to the desired number of top features to print
count = 0
for idx in non_zero_indices:
    if count < top_n:
        print(f"{feature_names[idx]}: {feature_importances[idx]}")
        count += 1
    else:
        break
# Out:
# cg15811515: 0.014544483952705427
# cg24833737: 0.01264952030667931
# cg22399133: 0.012349376293183091
# cg07149609: 0.012086932793835792
# cg19254119: 0.01142089719150566
# cg13879483: 0.011111654557939481
# cg08304190: 0.009947828788582807
# cg01893212: 0.00923129011375061
# cg26296488: 0.00870272984656808
# cg00100121: 0.008555321753851937

# %%
# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]

non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]

# Select the top 10 feature indices
top_n = 10  # Change this to the desired number of top features to visualize
selected_indices = non_zero_indices[:top_n]

# Print the top 10 feature importances
for idx in selected_indices:
    print(f"{feature_names[idx]}: {feature_importances[idx]}")

# Visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_indices)), feature_importances[selected_indices])
plt.xticks(range(len(selected_indices)), [feature_names[i] for i in selected_indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Top 10 Feature Importances from RandomForestClassifier (Non-zero Importance)")
plt.tight_layout()
plt.show()
# Out:
# cg15811515: 0.014544483952705427
# cg24833737: 0.01264952030667931
# cg22399133: 0.012349376293183091
# cg07149609: 0.012086932793835792
# cg19254119: 0.01142089719150566
# cg13879483: 0.011111654557939481
# cg08304190: 0.009947828788582807
# cg01893212: 0.00923129011375061
# cg26296488: 0.00870272984656808
# cg00100121: 0.008555321753851937

# %%
forest.fit(X_filtered, Y_train)

#Now predict on test data using the trained model. 

#First apply feature selector transform to make sure same features are selected from test data
X_test_filtered = feat_selector.transform(X_test)
prediction_forest = forest.predict(X_test_filtered)


#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(Y_test, prediction_forest))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, prediction_forest)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.9736842105263158
# <AxesSubplot:>
