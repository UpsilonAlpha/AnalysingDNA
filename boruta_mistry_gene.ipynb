# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_gene = pd.read_csv("mystery_gene-expr.csv")
df_gene
# Out:
#           Unnamed: 0                Label  ..100130426  ..100133144  \
# 0    TCGA.BH.A0EI.01        Primary Tumor       0.0000       6.4349
# 1    TCGA.EW.A1P4.01        Primary Tumor       0.0000       1.0744
# 2    TCGA.A2.A0CM.01        Primary Tumor       0.0000      19.7115
# 3    TCGA.AO.A12B.01        Primary Tumor       0.0000       2.0510
# 4    TCGA.E2.A576.01        Primary Tumor       0.0000       2.3190
# ..               ...                  ...          ...          ...
# 375  TCGA.56.7582.11  Solid Tissue Normal       0.0000      20.6902
# 376  TCGA.43.3394.11  Solid Tissue Normal       0.0000       2.3955
# 377  TCGA.92.7340.11  Solid Tissue Normal       0.0000      13.5526
# 378  TCGA.22.5471.11  Solid Tissue Normal       0.4281       2.1404
# 379  TCGA.39.5040.11  Solid Tissue Normal       0.0000      15.6350
#
#      ..100134869   ..10357    ..10431  ..136542  ..155060  ..26823  ...  \
# 0         7.4701   93.2677   584.7818       0.0  378.9108   0.0000  ...
# 1         2.7221  130.9719  1260.8200       0.0  111.6173   0.0000  ...
# 2         3.8260  238.3801  1431.6372       0.0  125.9952   0.0000  ...
# 3         0.4863   62.7720   749.3393       0.0  276.5620   0.0000  ...
# 4         9.1384   78.9413  1686.9844       0.0  340.5133   0.4583  ...
# ..           ...       ...        ...       ...       ...      ...  ...
# 375       7.2740   91.3830   532.9844       0.0  204.0721   0.9987  ...
# 376      10.0695  104.3228   393.2881       0.0   50.6592   0.1598  ...
# 377       3.7880   75.6230   495.4032       0.0   87.8989   0.8969  ...
# 378       8.9897  112.6199   525.6849       0.0   44.9486   0.0000  ...
# 379      10.7728  153.5417  1052.4272       0.0  163.1068   0.0000  ...
#
#      SYS1.DBNDD2.767557  TMED7.TICAM2.100302736  TMEM189.UBE2V1.387522  \
# 0                   NaN                     NaN                    NaN
# 1                   NaN                     NaN                    NaN
# 2                   NaN                     NaN                    NaN
# 3                   NaN                     NaN                    NaN
# 4                   NaN                     NaN                    NaN
# ..                  ...                     ...                    ...
# 375                 NaN                     NaN                    NaN
# 376                 NaN                     NaN                    NaN
# 377                 NaN                     NaN                    NaN
# 378                 NaN                     NaN                    NaN
# 379                 NaN                     NaN                    NaN
#
#      TNFSF12.TNFSF13.407977  TRIM6.TRIM34.445372  TSNAX.DISC1.100303453  \
# 0                       NaN                  NaN                    NaN
# 1                       NaN                  NaN                    NaN
# 2                       NaN                  NaN                    NaN
# 3                       NaN                  NaN                    NaN
# 4                       NaN                  NaN                    NaN
# ..                      ...                  ...                    ...
# 375                     NaN                  NaN                    NaN
# 376                     NaN                  NaN                    NaN
# 377                     NaN                  NaN                    NaN
# 378                     NaN                  NaN                    NaN
# 379                     NaN                  NaN                    NaN
#
#      VTRNA1.1.56664  VTRNA1.2.56663  VTRNA1.3.56662  ZFP91.CNTF.386607
# 0               NaN             NaN             NaN                NaN
# 1               NaN             NaN             NaN                NaN
# 2               NaN             NaN             NaN                NaN
# 3               NaN             NaN             NaN                NaN
# 4               NaN             NaN             NaN                NaN
# ..              ...             ...             ...                ...
# 375             NaN             NaN             NaN                NaN
# 376             NaN             NaN             NaN                NaN
# 377             NaN             NaN             NaN                NaN
# 378             NaN             NaN             NaN                NaN
# 379             NaN             NaN             NaN                NaN
#
# [380 rows x 20823 columns]

# %%
import pandas as pd

# 假设你已经有一个名为df_dna的DataFrame

# 使用isna()方法检查每一列中的NaN值，并使用sum()方法计算每一列的NaN数量
nan_counts = df_gene.isna().sum()

# 打印每一列的NaN数量
print(nan_counts)
# Out:
# Unnamed: 0                 0
# Label                      0
# ..100130426               76
# ..100133144               76
# ..100134869               76
#                         ...
# TSNAX.DISC1.100303453    304
# VTRNA1.1.56664           304
# VTRNA1.2.56663           304
# VTRNA1.3.56662           304
# ZFP91.CNTF.386607        304
# Length: 20823, dtype: int64

# %%
df_gene.info()
df_gene.isna().head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 20823 entries, Unnamed: 0 to ZFP91.CNTF.386607
# dtypes: float64(20821), object(2)
# memory usage: 60.4+ MB
#    Unnamed: 0  Label  ..100130426  ..100133144  ..100134869  ..10357  ..10431  \
# 0       False  False        False        False        False    False    False
# 1       False  False        False        False        False    False    False
# 2       False  False        False        False        False    False    False
# 3       False  False        False        False        False    False    False
# 4       False  False        False        False        False    False    False
#
#    ..136542  ..155060  ..26823  ...  SYS1.DBNDD2.767557  \
# 0     False     False    False  ...                True
# 1     False     False    False  ...                True
# 2     False     False    False  ...                True
# 3     False     False    False  ...                True
# 4     False     False    False  ...                True
#
#    TMED7.TICAM2.100302736  TMEM189.UBE2V1.387522  TNFSF12.TNFSF13.407977  \
# 0                    True                   True                    True
# 1                    True                   True                    True
# 2                    True                   True                    True
# 3                    True                   True                    True
# 4                    True                   True                    True
#
#    TRIM6.TRIM34.445372  TSNAX.DISC1.100303453  VTRNA1.1.56664  VTRNA1.2.56663  \
# 0                 True                   True            True            True
# 1                 True                   True            True            True
# 2                 True                   True            True            True
# 3                 True                   True            True            True
# 4                 True                   True            True            True
#
#    VTRNA1.3.56662  ZFP91.CNTF.386607
# 0            True               True
# 1            True               True
# 2            True               True
# 3            True               True
# 4            True               True
#
# [5 rows x 20823 columns]

# %%
# rename the dataset to label
unique_labels = df_gene.iloc[:, 1].unique()

# print the name of the classification
for label in unique_labels:
    print(label)
    
df_gene = df_gene.rename(columns = {'Primary Tumor':'0'})
df_gene
# Out:
# Primary Tumor
# Solid Tissue Normal
#           Unnamed: 0                Label  ..100130426  ..100133144  \
# 0    TCGA.BH.A0EI.01        Primary Tumor       0.0000       6.4349
# 1    TCGA.EW.A1P4.01        Primary Tumor       0.0000       1.0744
# 2    TCGA.A2.A0CM.01        Primary Tumor       0.0000      19.7115
# 3    TCGA.AO.A12B.01        Primary Tumor       0.0000       2.0510
# 4    TCGA.E2.A576.01        Primary Tumor       0.0000       2.3190
# ..               ...                  ...          ...          ...
# 375  TCGA.56.7582.11  Solid Tissue Normal       0.0000      20.6902
# 376  TCGA.43.3394.11  Solid Tissue Normal       0.0000       2.3955
# 377  TCGA.92.7340.11  Solid Tissue Normal       0.0000      13.5526
# 378  TCGA.22.5471.11  Solid Tissue Normal       0.4281       2.1404
# 379  TCGA.39.5040.11  Solid Tissue Normal       0.0000      15.6350
#
#      ..100134869   ..10357    ..10431  ..136542  ..155060  ..26823  ...  \
# 0         7.4701   93.2677   584.7818       0.0  378.9108   0.0000  ...
# 1         2.7221  130.9719  1260.8200       0.0  111.6173   0.0000  ...
# 2         3.8260  238.3801  1431.6372       0.0  125.9952   0.0000  ...
# 3         0.4863   62.7720   749.3393       0.0  276.5620   0.0000  ...
# 4         9.1384   78.9413  1686.9844       0.0  340.5133   0.4583  ...
# ..           ...       ...        ...       ...       ...      ...  ...
# 375       7.2740   91.3830   532.9844       0.0  204.0721   0.9987  ...
# 376      10.0695  104.3228   393.2881       0.0   50.6592   0.1598  ...
# 377       3.7880   75.6230   495.4032       0.0   87.8989   0.8969  ...
# 378       8.9897  112.6199   525.6849       0.0   44.9486   0.0000  ...
# 379      10.7728  153.5417  1052.4272       0.0  163.1068   0.0000  ...
#
#      SYS1.DBNDD2.767557  TMED7.TICAM2.100302736  TMEM189.UBE2V1.387522  \
# 0                   NaN                     NaN                    NaN
# 1                   NaN                     NaN                    NaN
# 2                   NaN                     NaN                    NaN
# 3                   NaN                     NaN                    NaN
# 4                   NaN                     NaN                    NaN
# ..                  ...                     ...                    ...
# 375                 NaN                     NaN                    NaN
# 376                 NaN                     NaN                    NaN
# 377                 NaN                     NaN                    NaN
# 378                 NaN                     NaN                    NaN
# 379                 NaN                     NaN                    NaN
#
#      TNFSF12.TNFSF13.407977  TRIM6.TRIM34.445372  TSNAX.DISC1.100303453  \
# 0                       NaN                  NaN                    NaN
# 1                       NaN                  NaN                    NaN
# 2                       NaN                  NaN                    NaN
# 3                       NaN                  NaN                    NaN
# 4                       NaN                  NaN                    NaN
# ..                      ...                  ...                    ...
# 375                     NaN                  NaN                    NaN
# 376                     NaN                  NaN                    NaN
# 377                     NaN                  NaN                    NaN
# 378                     NaN                  NaN                    NaN
# 379                     NaN                  NaN                    NaN
#
#      VTRNA1.1.56664  VTRNA1.2.56663  VTRNA1.3.56662  ZFP91.CNTF.386607
# 0               NaN             NaN             NaN                NaN
# 1               NaN             NaN             NaN                NaN
# 2               NaN             NaN             NaN                NaN
# 3               NaN             NaN             NaN                NaN
# 4               NaN             NaN             NaN                NaN
# ..              ...             ...             ...                ...
# 375             NaN             NaN             NaN                NaN
# 376             NaN             NaN             NaN                NaN
# 377             NaN             NaN             NaN                NaN
# 378             NaN             NaN             NaN                NaN
# 379             NaN             NaN             NaN                NaN
#
# [380 rows x 20823 columns]

# %%
df_gene['Label'].value_counts()
# Out:
# Primary Tumor          190
# Solid Tissue Normal    190
# Name: Label, dtype: int64

# %%
# define the dependt variable that need to be predicted 
y = df_gene['Label'].values

# encoding catergorical data
from sklearn.preprocessing import LabelEncoder
Labelencoder = LabelEncoder()
Y = Labelencoder.fit_transform(y) # Primary Tumor = 0, Solid Tissue Normal = 1

# %%
# define x and normalization
# Define the independent variables to drop the Label and Unnamed: 0
X = df_gene.drop(labels = ['Label','Unnamed: 0'], axis = 1)

import numpy as np
feature_names = np.array(X.columns)

# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
array_ = np.zeros((10000,10000),dtype='float32') # 默认float64

# %%
# 创建一个IterativeImputer对象
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
# 使用fit_transform方法执行插补，将缺失值替换为回归估计值
imputed_data = imputer.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12420\1640939531.py in <module>
#       1 # 使用fit_transform方法执行插补，将缺失值替换为回归估计值
# ----> 2 imputed_data = imputer.fit_transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in fit_transform(self, X, y)
#     662                     n_features, feat_idx, abs_corr_mat
#     663                 )
# --> 664                 Xt, estimator = self._impute_one_feature(
#     665                     Xt,
#     666                     mask_missing_values,
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_iterative.py in _impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     315             X_train = _safe_indexing(X_filled[:, neighbor_feat_idx], ~missing_row_mask)
#     316             y_train = _safe_indexing(X_filled[:, feat_idx], ~missing_row_mask)
# --> 317             estimator.fit(X_train, y_train)
#     318
#     319         # if no missing values, don't predict
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_bayes.py in fit(self, X, y, sample_weight)
#     332             Vh.T, Vh / (eigen_vals_ + lambda_ / alpha_)[:, np.newaxis]
#     333         )
# --> 334         self.sigma_ = (1.0 / alpha_) * scaled_sigma_
#     335
#     336         self._set_intercept(X_offset_, y_offset_, X_scale_)
#
# MemoryError: Unable to allocate 3.23 GiB for an array with shape (20820, 20820) and data type float64

# %%
# 将插补后的数据转换回DataFrame格式
imputed_df = pd.DataFrame(imputed_data, columns=data.columns)

# 打印插补后的DataFrame
print("插补后的DataFrame：")
print(imputed_df)

# %%
X = X.fillna(0.000001)
X = X + 0.000001
print("替换后的 DataFrame：")
print(X)
# Out:
# 替换后的 DataFrame：
#      ..100130426  ..100133144  ..100134869     ..10357      ..10431  ..136542  \
# 0       0.000001     6.434901     7.470101   93.267701   584.781801  0.000001
# 1       0.000001     1.074401     2.722101  130.971901  1260.820001  0.000001
# 2       0.000001    19.711501     3.826001  238.380101  1431.637201  0.000001
# 3       0.000001     2.051001     0.486301   62.772001   749.339301  0.000001
# 4       0.000001     2.319001     9.138401   78.941301  1686.984401  0.000001
# ..           ...          ...          ...         ...          ...       ...
# 375     0.000001    20.690201     7.274001   91.383001   532.984401  0.000001
# 376     0.000001     2.395501    10.069501  104.322801   393.288101  0.000001
# 377     0.000001    13.552601     3.788001   75.623001   495.403201  0.000001
# 378     0.428101     2.140401     8.989701  112.619901   525.684901  0.000001
# 379     0.000001    15.635001    10.772801  153.541701  1052.427201  0.000001
#
#        ..155060   ..26823  ..280660  ..317712  ...  SYS1.DBNDD2.767557  \
# 0    378.910801  0.000001  0.000001  0.000001  ...            0.000002
# 1    111.617301  0.000001  0.000001  0.000001  ...            0.000002
# 2    125.995201  0.000001  0.000001  0.000001  ...            0.000002
# 3    276.562001  0.000001  0.000001  0.000001  ...            0.000002
# 4    340.513301  0.458301  0.000001  0.000001  ...            0.000002
# ..          ...       ...       ...       ...  ...                 ...
# 375  204.072101  0.998701  0.000001  0.000001  ...            0.000002
# 376   50.659201  0.159801  0.000001  0.000001  ...            0.000002
# 377   87.898901  0.896901  0.000001  0.000001  ...            0.000002
# 378   44.948601  0.000001  0.000001  0.000001  ...            0.000002
# 379  163.106801  0.000001  0.000001  0.000001  ...            0.000002
#
#      TMED7.TICAM2.100302736  TMEM189.UBE2V1.387522  TNFSF12.TNFSF13.407977  \
# 0                  0.000002               0.000002                0.000002
# 1                  0.000002               0.000002                0.000002
# 2                  0.000002               0.000002                0.000002
# 3                  0.000002               0.000002                0.000002
# 4                  0.000002               0.000002                0.000002
# ..                      ...                    ...                     ...
# 375                0.000002               0.000002                0.000002
# 376                0.000002               0.000002                0.000002
# 377                0.000002               0.000002                0.000002
# 378                0.000002               0.000002                0.000002
# 379                0.000002               0.000002                0.000002
#
#      TRIM6.TRIM34.445372  TSNAX.DISC1.100303453  VTRNA1.1.56664  \
# 0               0.000002               0.000002        0.000002
# 1               0.000002               0.000002        0.000002
# 2               0.000002               0.000002        0.000002
# 3               0.000002               0.000002        0.000002
# 4               0.000002               0.000002        0.000002
# ..                   ...                    ...             ...
# 375             0.000002               0.000002        0.000002
# 376             0.000002               0.000002        0.000002
# 377             0.000002               0.000002        0.000002
# 378             0.000002               0.000002        0.000002
# 379             0.000002               0.000002        0.000002
#
#      VTRNA1.2.56663  VTRNA1.3.56662  ZFP91.CNTF.386607
# 0          0.000002        0.000002           0.000002
# 1          0.000002        0.000002           0.000002
# 2          0.000002        0.000002           0.000002
# 3          0.000002        0.000002           0.000002
# 4          0.000002        0.000002           0.000002
# ..              ...             ...                ...
# 375        0.000002        0.000002           0.000002
# 376        0.000002        0.000002           0.000002
# 377        0.000002        0.000002           0.000002
# 378        0.000002        0.000002           0.000002
# 379        0.000002        0.000002           0.000002
#
# [380 rows x 20821 columns]

# %%
# normalization
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
# log2
# 标准缩放（Standard Scaler）
#scaler = StandardScaler()
X_log2 = np.log2(X)
#X_log2 = X_log2.values.reshape(-1, 1)  # 将数据转换为二维数组
#X_log2 = scaler.fit_transform(X_log2)
print(X_log2)
print()
# Out:
#      ..100130426  ..100133144  ..100134869   ..10357    ..10431   ..136542  \
# 0     -19.931569     2.685918     2.901128  6.543306   9.191755 -19.931569
# 1     -19.931569     0.103533     1.444721  7.033114  10.300147 -19.931569
# 2     -19.931569     4.300966     1.935837  7.897120  10.483450 -19.931569
# 3     -19.931569     1.036328    -1.040079  5.972049   9.549475 -19.931569
# 4     -19.931569     1.213503     3.191942  6.302708  10.720231 -19.931569
# ..           ...          ...          ...       ...        ...        ...
# 375   -19.931569     4.370876     2.862749  6.513854   9.057949 -19.931569
# 376   -19.931569     1.260327     3.331920  6.704911   8.619443 -19.931569
# 377   -19.931569     3.760498     1.921437  6.240753   8.952459 -19.931569
# 378    -1.223977     1.097881     3.168273  6.815318   9.038054 -19.931569
# 379   -19.931569     3.966707     3.429322  7.262487  10.039505 -19.931569
#
#      ..155060    ..26823   ..280660   ..317712  ...  SYS1.DBNDD2.767557  \
# 0    8.565714 -19.931569 -19.931569 -19.931569  ...          -18.931569
# 1    6.802417 -19.931569 -19.931569 -19.931569  ...          -18.931569
# 2    6.977225 -19.931569 -19.931569 -19.931569  ...          -18.931569
# 3    8.111459 -19.931569 -19.931569 -19.931569  ...          -18.931569
# 4    8.411567  -1.125633 -19.931569 -19.931569  ...          -18.931569
# ..        ...        ...        ...        ...  ...                 ...
# 375  7.672935  -0.001875 -19.931569 -19.931569  ...          -18.931569
# 376  5.662752  -2.645652 -19.931569 -19.931569  ...          -18.931569
# 377  6.457773  -0.156979 -19.931569 -19.931569  ...          -18.931569
# 378  5.490204 -19.931569 -19.931569 -19.931569  ...          -18.931569
# 379  7.349673 -19.931569 -19.931569 -19.931569  ...          -18.931569
#
#      TMED7.TICAM2.100302736  TMEM189.UBE2V1.387522  TNFSF12.TNFSF13.407977  \
# 0                -18.931569             -18.931569              -18.931569
# 1                -18.931569             -18.931569              -18.931569
# 2                -18.931569             -18.931569              -18.931569
# 3                -18.931569             -18.931569              -18.931569
# 4                -18.931569             -18.931569              -18.931569
# ..                      ...                    ...                     ...
# 375              -18.931569             -18.931569              -18.931569
# 376              -18.931569             -18.931569              -18.931569
# 377              -18.931569             -18.931569              -18.931569
# 378              -18.931569             -18.931569              -18.931569
# 379              -18.931569             -18.931569              -18.931569
#
#      TRIM6.TRIM34.445372  TSNAX.DISC1.100303453  VTRNA1.1.56664  \
# 0             -18.931569             -18.931569      -18.931569
# 1             -18.931569             -18.931569      -18.931569
# 2             -18.931569             -18.931569      -18.931569
# 3             -18.931569             -18.931569      -18.931569
# 4             -18.931569             -18.931569      -18.931569
# ..                   ...                    ...             ...
# 375           -18.931569             -18.931569      -18.931569
# 376           -18.931569             -18.931569      -18.931569
# 377           -18.931569             -18.931569      -18.931569
# 378           -18.931569             -18.931569      -18.931569
# 379           -18.931569             -18.931569      -18.931569
#
#      VTRNA1.2.56663  VTRNA1.3.56662  ZFP91.CNTF.386607
# 0        -18.931569      -18.931569         -18.931569
# 1        -18.931569      -18.931569         -18.931569
# 2        -18.931569      -18.931569         -18.931569
# 3        -18.931569      -18.931569         -18.931569
# 4        -18.931569      -18.931569         -18.931569
# ..              ...             ...                ...
# 375      -18.931569      -18.931569         -18.931569
# 376      -18.931569      -18.931569         -18.931569
# 377      -18.931569      -18.931569         -18.931569
# 378      -18.931569      -18.931569         -18.931569
# 379      -18.931569      -18.931569         -18.931569
#
# [380 rows x 20821 columns]

# %%
# split the data into train and test to verify accuracy after fitting 
# standard-scaler
scaler = StandardScaler()
scaler.fit(X)
X_scale = scaler.transform(X)
print(X_scale)
print()

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_log2, Y, test_size = 0.3, random_state = 42)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# [[-0.22855547 -0.12036556  0.0399294  ...  0.5         0.5
#   -0.19183424]
#  [-0.22855547 -0.6647285  -0.50175601 ...  0.5         0.5
#   -0.19183424]
#  [-0.22855547  1.22788347 -0.37581529 ...  0.5         0.5
#   -0.19183424]
#  ...
#  [-0.22855547  0.60244239 -0.3801506  ...  0.5         0.5
#   -0.19183424]
#  [ 4.31341877 -0.55647537  0.21329611 ...  0.5         0.5
#   -0.19183424]
#  [-0.22855547  0.81391173  0.41672477 ...  0.5         0.5
#   -0.19183424]]

# %%
# define classifier using the Boruta
import xgboost as xgb
model = xgb. XGBClassifier()
from boruta import BorutaPy
feat_selector = BorutaPy(model, n_estimators = 'auto', verbose = 2, random_state = 1)
feat_selector.fit(X_train, Y_train)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	20821
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	51
# Rejected: 	20770
# Iteration: 	9 / 100
# Confirmed: 	14
# Tentative: 	37
# Rejected: 	20770
# Iteration: 	10 / 100
# Confirmed: 	14
# Tentative: 	37
# Rejected: 	20770
# Iteration: 	11 / 100
# Confirmed: 	14
# Tentative: 	37
# Rejected: 	20770
# Iteration: 	12 / 100
# Confirmed: 	24
# Tentative: 	27
# Rejected: 	20770
# Iteration: 	13 / 100
# Confirmed: 	24
# Tentative: 	27
# Rejected: 	20770
# Iteration: 	14 / 100
# Confirmed: 	24
# Tentative: 	27
# Rejected: 	20770
# Iteration: 	15 / 100
# Confirmed: 	24
# Tentative: 	27
# Rejected: 	20770
# Iteration: 	16 / 100
# Confirmed: 	25
# Tentative: 	26
# Rejected: 	20770
# Iteration: 	17 / 100
# Confirmed: 	25
# Tentative: 	26
# Rejected: 	20770
# Iteration: 	18 / 100
# Confirmed: 	25
# Tentative: 	25
# Rejected: 	20771
# Iteration: 	19 / 100
# Confirmed: 	30
# Tentative: 	20
# Rejected: 	20771
# Iteration: 	20 / 100
# Confirmed: 	30
# Tentative: 	20
# Rejected: 	20771
# Iteration: 	21 / 100
# Confirmed: 	30
# Tentative: 	20
# Rejected: 	20771
# Iteration: 	22 / 100
# Confirmed: 	33
# Tentative: 	17
# Rejected: 	20771
# Iteration: 	23 / 100
# Confirmed: 	33
# Tentative: 	17
# Rejected: 	20771
# Iteration: 	24 / 100
# Confirmed: 	33
# Tentative: 	17
# Rejected: 	20771
# Iteration: 	25 / 100
# Confirmed: 	33
# Tentative: 	17
# Rejected: 	20771
# Iteration: 	26 / 100
# Confirmed: 	50
# Tentative: 	0
# Rejected: 	20771
#
#
# BorutaPy finished running.
#
# Iteration: 	27 / 100
# Confirmed: 	50
# Tentative: 	0
# Rejected: 	20771
# BorutaPy(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                  colsample_bylevel=None, colsample_bynode=None,
#                                  colsample_bytree=None,
#                                  early_stopping_rounds=None,
#                                  enable_categorical=False, eval_metric=None,
#                                  feature_types=None, gamma=None, gpu_id=None,
#                                  grow_policy=None, importance_type=None,
#                                  interaction_constraints=None,
#                                  learning_rate=None, max_bin=None,
#                                  max_cat_threshold=None, max_cat_to_onehot=None,
#                                  max_delta_step=None, max_depth=None,
#                                  max_leaves=None, min_child_weight=None,
#                                  missing=nan, monotone_constraints=None,
#                                  n_estimators=100, n_jobs=None,
#                                  num_parallel_tree=None, predictor=None,
#                                  random_state=1291602952, ...),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x29E80049840, verbose=2)

# %%
#  check the selected features
print(feat_selector.support_) # should we accept the feature or not
# check the ranking of the features
print(feat_selector.ranking_)
# filter down the selected features
X_filtered = feat_selector.transform(X_train)
# Out:
# [False False  True ... False False False]
# [10399 10399     1 ... 10399 10399 10399]

# %%
# review the features
# zip feature names, ranks and decisions
feature_ranks = list(zip(feature_names, 
                         feat_selector.ranking_, 
                         feat_selector.support_))
cnt = 0
for feat in feature_ranks:
    if feat[2] == True:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        cnt += 1
print(cnt)
# Out:
# Feature: ..100134869                    Rank: 1,  Keep: True
# Feature: ..57714                        Rank: 1,  Keep: True
# Feature: AAAS.8086                      Rank: 1,  Keep: True
# Feature: AARS2.57505                    Rank: 1,  Keep: True
# Feature: AASDH.132949                   Rank: 1,  Keep: True
# Feature: ABCA6.23460                    Rank: 1,  Keep: True
# Feature: ABCA8.10351                    Rank: 1,  Keep: True
# Feature: ABCF1.23                       Rank: 1,  Keep: True
# Feature: ACBD6.84320                    Rank: 1,  Keep: True
# Feature: ACVRL1.94                      Rank: 1,  Keep: True
# Feature: ANGPTL1.9068                   Rank: 1,  Keep: True
# Feature: C1QTNF7.114905                 Rank: 1,  Keep: True
# Feature: CCDC69.26112                   Rank: 1,  Keep: True
# Feature: CDC6.990                       Rank: 1,  Keep: True
# Feature: CDKN2A.1029                    Rank: 1,  Keep: True
# Feature: DCN.1634                       Rank: 1,  Keep: True
# Feature: DDX39.10212                    Rank: 1,  Keep: True
# Feature: FAM128A.653784                 Rank: 1,  Keep: True
# Feature: FBXO43.286151                  Rank: 1,  Keep: True
# Feature: GANC.2595                      Rank: 1,  Keep: True
# Feature: GPR142.350383                  Rank: 1,  Keep: True
# Feature: HIST1H2AE.3012                 Rank: 1,  Keep: True
# Feature: HPSE2.60495                    Rank: 1,  Keep: True
# Feature: KIAA0802.23255                 Rank: 1,  Keep: True
# Feature: LOC285830.285830               Rank: 1,  Keep: True
# Feature: LYVE1.10894                    Rank: 1,  Keep: True
# Feature: MAMDC2.256691                  Rank: 1,  Keep: True
# Feature: MAZ.4150                       Rank: 1,  Keep: True
# Feature: MMP11.4320                     Rank: 1,  Keep: True
# Feature: MMP14.4323                     Rank: 1,  Keep: True
# Feature: MSTO1.55154                    Rank: 1,  Keep: True
# Feature: MT1M.4499                      Rank: 1,  Keep: True
# Feature: NCRNA00092.100188953           Rank: 1,  Keep: True
# Feature: NR3C2.4306                     Rank: 1,  Keep: True
# Feature: NUF2.83540                     Rank: 1,  Keep: True
# Feature: PCDHB10.56126                  Rank: 1,  Keep: True
# Feature: PIK3R6.146850                  Rank: 1,  Keep: True
# Feature: PSPH.5723                      Rank: 1,  Keep: True
# Feature: PTCD1.26024                    Rank: 1,  Keep: True
# Feature: PTPN21.11099                   Rank: 1,  Keep: True
# Feature: QSOX2.169714                   Rank: 1,  Keep: True
# Feature: RBM39.9584                     Rank: 1,  Keep: True
# Feature: SEMA6D.80031                   Rank: 1,  Keep: True
# Feature: SPRY2.10253                    Rank: 1,  Keep: True
# Feature: SULF2.55959                    Rank: 1,  Keep: True
# Feature: TNXB.7148                      Rank: 1,  Keep: True
# Feature: TRIM59.286827                  Rank: 1,  Keep: True
# Feature: UBL3.5412                      Rank: 1,  Keep: True
# Feature: UBQLN4.56893                   Rank: 1,  Keep: True
# Feature: ZNF518B.85460                  Rank: 1,  Keep: True
# 50

# %%
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# from sklearn.feature_selection import SelectFromModel
from sklearn.tree import plot_tree
import numpy as np

forest = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
forest.fit(X_train, Y_train)
feature_importances = forest.feature_importances_
print(feature_importances)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]
non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]
# Print the top 10 feature importances
top_n = 10  # Change this to the desired number of top features to print
count = 0
for idx in non_zero_indices:
    if count < top_n:
        print(f"{feature_names[idx]}: {feature_importances[idx]}")
        count += 1
    else:
        break
# Out:
# IBSP.3381: 0.017118902373628966
# C7orf58.79974: 0.016835028119702465
# ADH1A.124: 0.01117718322069656
# C1QTNF7.114905: 0.0099961989862618
# GPRIN1.114787: 0.00950726132654486
# NAT9.26151: 0.00942093134101589
# QSOX2.169714: 0.009291918656014182
# PUS7.54517: 0.009281632641755948
# FIGNL1.63979: 0.008429815962920357
# RIC3.79608: 0.007712638676100159

# %%
# Sort the features by importance in descending order
sorted_indices = feature_importances.argsort()[::-1]

non_zero_indices = sorted_indices[feature_importances[sorted_indices] > 0]

# Select the top 10 feature indices
top_n = 10  # Change this to the desired number of top features to visualize
selected_indices = non_zero_indices[:top_n]

# Print the top 10 feature importances
for idx in selected_indices:
    print(f"{feature_names[idx]}: {feature_importances[idx]}")

# Visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_indices)), feature_importances[selected_indices])
plt.xticks(range(len(selected_indices)), [feature_names[i] for i in selected_indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Top 10 Feature Importances from RandomForestClassifier (Non-zero Importance)")
plt.tight_layout()
plt.show()
# Out:
# IBSP.3381: 0.017118902373628966
# C7orf58.79974: 0.016835028119702465
# ADH1A.124: 0.01117718322069656
# C1QTNF7.114905: 0.0099961989862618
# GPRIN1.114787: 0.00950726132654486
# NAT9.26151: 0.00942093134101589
# QSOX2.169714: 0.009291918656014182
# PUS7.54517: 0.009281632641755948
# FIGNL1.63979: 0.008429815962920357
# RIC3.79608: 0.007712638676100159

# %%
forest.fit(X_filtered, Y_train)

#Now predict on test data using the trained model. 

#First apply feature selector transform to make sure same features are selected from test data
X_test_filtered = feat_selector.transform(X_test)
prediction_forest = forest.predict(X_test_filtered)

#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(Y_test, prediction_forest))
print("True Possitive = ", )

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, prediction_forest)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.9912280701754386
# <AxesSubplot:>
